# %%
from IPython.display import Image, clear_output  # to display images

# %% [markdown]
# # Requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Run
#
# The results are stored at 'results/' and 'runs/' folder

# %%
# !python detect.py --save-txt --weights best.pt --conf 0.4 --source ../images/fire1.jpg --model_dist model@1535470106.json --weights_dist model@1535470106.h5
# Out:
# here 1st
# here 2nd
# [0, 246, 263, 403, 465, 424.35, 157.54792332268372, 695.1750000000001, 278.55431309904156]
# Loaded model from disk
#
# ...
# 1/1 [==============================] - 0s 341ms/step
# [[     39.765]]
# here 3rd
# here 2nd
# [0, 284, 24, 474, 257, 489.9, 14.37699680511182, 817.65, 153.95367412140575]
# Loaded model from disk
#
# ...
# 1/1 [==============================] - 0s 219ms/step
# [[     40.716]
#  [     45.865]]
# here 3rd
# detect: weights=['best.pt'], source=../images/fire1.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, model_dist=model@1535470106.json, weights_dist=model@1535470106.h5
# ...

# %%
Image(filename='runs/detect/exp4/fire1.jpg', width=600)

# %%
Image(filename='results/frames/0.png', width=600)

# %% [markdown]
# Both give the same result, except the 'results/' folder changes every run

# %%
# !python detect.py --save-txt --weights best.pt --conf 0.4 --source ../images/fire5.jpg --model_dist model@1535470106.json --weights_dist model@1535470106.h5
# Out:
# here 1st
# detect: weights=['best.pt'], source=../images/fire5.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, model_dist=model@1535470106.json, weights_dist=model@1535470106.h5
# YOLOv5  2022-9-5 Python-3.11.3 torch-2.1.0.dev20230610+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# Fusing layers...
# YOLOv5s_fs summary: 232 layers, 7249215 parameters, 0 gradients
# image 1/1 C:\Users\Nub\Downloads\Compressed\YOLOER_V1-master\YOLOER_V1-master\images\fire5.jpg: 384x640 1 fire, Done. (0.138s)
# Speed: 0.0ms pre-process, 138.0ms inference, 3.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\exp5
# ...

# %%
Image(filename='runs/detect/exp4/fire1.jpg',width=600)

# %%
Image(filename='results/frames/0.png', width=600)

# %% [markdown]
# For this run the results saved at 'runs/exp5/fire5.jpg'

# %%
Image(filename='runs/detect/exp5/fire5.jpg',width=600)

# %% [markdown]
# # Command

# %%
Usage - sources:
    $ python path/to/detect.py --weights yolov5s.pt --source 0              # webcam
                                                             img.jpg        # image
                                                             vid.mp4        # video
                                                             path/          # directory
                                                             path/*.jpg     # glob
                                                             'https://youtu.be/Zgi9g1ksQHc'  # YouTube
                                                             'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream

Usage - formats:
    $ python path/to/detect.py --weights yolov5s.pt                 # PyTorch
                                         yolov5s.torchscript        # TorchScript
                                         yolov5s.onnx               # ONNX Runtime or OpenCV DNN with --dnn
                                         yolov5s.xml                # OpenVINO
                                         yolov5s.engine             # TensorRT
                                         yolov5s.mlmodel            # CoreML (macOS-only)
                                         yolov5s_saved_model        # TensorFlow SavedModel
                                         yolov5s.pb                 # TensorFlow GraphDef
                                         yolov5s.tflite             # TensorFlow Lite
                                         yolov5s_edgetpu.tflite     # TensorFlow Edge TPU
